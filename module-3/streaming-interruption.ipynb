# %% [markdown]
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/langchain-ai/langchain-academy/blob/main/module-3/streaming-interruption.ipynb) [![Open in LangChain Academy](https://cdn.prod.website-files.com/65b8cd72835ceeacd4449a53/66e9eba12c7b7688aa3dbb5e_LCA-badge-green.svg)](https://academy.langchain.com/courses/take/intro-to-langgraph/lessons/58239464-lesson-1-streaming)

# %% [markdown]
# # Streaming
#
# ## Review
#
# In module 2, covered a few ways to customize graph state and memory.
#
# We built up to a Chatbot with external memory that can sustain long-running conversations.
#
# ## Goals
#
# This module will dive into `human-in-the-loop`, which builds on memory and allows users to interact directly with graphs in various ways.
#
# To set the stage for `human-in-the-loop`, we'll first dive into streaming, which provides several ways to visualize graph output (e.g., node state or chat model tokens) over the course of execution.

# %%
# %%capture --no-stderr
# %pip install --quiet -U langgraph langchain_openai langgraph_sdk

# %% [markdown]
# ## Streaming
#
# LangGraph is built with [first class support for streaming](https://langchain-ai.github.io/langgraph/concepts/low_level/#streaming).
#
# Let's set up our Chatbot from Module 2, and show various way to stream outputs from the graph during execution.

# %%
# import os, getpass

# def _set_env(var: str):
#     if not os.environ.get(var):
#         os.environ[var] = getpass.getpass(f"{var}: ")

# _set_env("OPENAI_API_KEY")

# %%
from opentelemetry import trace
from opentelemetry.sdk.trace import TracerProvider
from opentelemetry.sdk.resources import Resource
from opentelemetry.sdk.trace.export import BatchSpanProcessor
from opentelemetry.exporter.otlp.proto.http.trace_exporter import OTLPSpanExporter

from openinference.instrumentation.langchain import LangChainInstrumentor
from langchain_ollama import ChatOllama
from langchain_core.messages import HumanMessage
from langchain_core.tools import tool

# %%
import os
from dotenv import load_dotenv

load_dotenv()
OLLAMA_API_KEY = os.getenv("OLLAMA_API_KEY")

# %%
# ---------- Tracing ----------
resource = Resource.create({
    "service.name": "agente-ollama-tools",
    "service.version": "1.0.0",
})

provider = TracerProvider(resource=resource)
provider.add_span_processor(
    BatchSpanProcessor(
        OTLPSpanExporter(endpoint="http://localhost:6006/v1/traces")
    )
)
trace.set_tracer_provider(provider)

LangChainInstrumentor().instrument()
# Out:
# Overriding of current TracerProvider is not allowed
# Attempting to instrument while already instrumented

# %%
import sys
sys.path.append("../")

from config import phoenix_config_

# %% [markdown]
# Note that we use `RunnableConfig` with `call_model` to enable token-wise streaming. This is [only needed with python < 3.11](https://langchain-ai.github.io/langgraph/how-tos/streaming-tokens/). We include in case you are running this notebook in CoLab, which will use python 3.x.

# %%
from IPython.display import Image, display

from langchain_openai import ChatOpenAI
from langchain_core.messages import SystemMessage, HumanMessage, RemoveMessage
from langchain_core.runnables import RunnableConfig

from langgraph.checkpoint.memory import MemorySaver
from langgraph.graph import StateGraph, START, END
from langgraph.graph import MessagesState

from langchain_ollama import ChatOllama

# LLM
# model = ChatOpenAI(model="gpt-4o", temperature=0) 
model = ChatOllama(model="gemma4:31b",
                    base_url="https://ollama.com",
                    client_kwargs={
                        "headers": {
                            "Authorization": f"Bearer {os.environ['OLLAMA_API_KEY']}"
                        }
                    },
                    temperature=0.01
                    )

# State 
class State(MessagesState):
    summary: str

# Define the logic to call the model
def call_model(state: State, config: RunnableConfig):
    
    # Get summary if it exists
    summary = state.get("summary", "")

    # If there is summary, then we add it
    if summary:
        
        # Add summary to system message
        system_message = f"Summary of conversation earlier: {summary}"

        # Append summary to any newer messages
        messages = [SystemMessage(content=system_message)] + state["messages"]
    
    else:
        messages = state["messages"]
    
    response = model.invoke(messages, config)
    return {"messages": response}

def summarize_conversation(state: State):
    
    # First, we get any existing summary
    summary = state.get("summary", "")

    # Create our summarization prompt 
    if summary:
        
        # A summary already exists
        summary_message = (
            f"This is summary of the conversation to date: {summary}\n\n"
            "Extend the summary by taking into account the new messages above:"
        )
        
    else:
        summary_message = "Create a summary of the conversation above:"

    # Add prompt to our history
    messages = state["messages"] + [HumanMessage(content=summary_message)]
    response = model.invoke(messages)
    
    # Delete all but the 2 most recent messages
    delete_messages = [RemoveMessage(id=m.id) for m in state["messages"][:-2]]
    return {"summary": response.content, "messages": delete_messages}

# Determine whether to end or summarize the conversation
def should_continue(state: State):
    
    """Return the next node to execute."""
    
    messages = state["messages"]
    
    # If there are more than six messages, then we summarize the conversation
    if len(messages) > 6:
        return "summarize_conversation"
    
    # Otherwise we can just end
    return END

# Define a new graph
workflow = StateGraph(State)
workflow.add_node("conversation", call_model)
workflow.add_node(summarize_conversation)

# Set the entrypoint as conversation
workflow.add_edge(START, "conversation")
workflow.add_conditional_edges("conversation", should_continue)
workflow.add_edge("summarize_conversation", END)

# Compile
memory = MemorySaver()
graph = workflow.compile(checkpointer=memory)
display(Image(graph.get_graph().draw_mermaid_png()))

# %% [markdown]
# ### Streaming full state
#
# Now, let's talk about ways to [stream our graph state](https://langchain-ai.github.io/langgraph/concepts/low_level/#streaming).
#
# `.stream` and `.astream` are sync and async methods for streaming back results.
#
# LangGraph supports a few [different streaming modes](https://langchain-ai.github.io/langgraph/how-tos/stream-values/) for [graph state](https://langchain-ai.github.io/langgraph/how-tos/stream-values/):
#
# * `values`: This streams the full state of the graph after each node is called.
# * `updates`: This streams updates to the state of the graph after each node is called.
#
# ![values_vs_updates.png](https://cdn.prod.website-files.com/65b8cd72835ceeacd4449a53/66dbaf892d24625a201744e5_streaming1.png)
#
# Let's look at `stream_mode="updates"`.
#
# Because we stream with `updates`, we only see updates to the state after node in the graph is run.
#
# Each `chunk` is a dict with `node_name` as the key and the updated state as the value.

# %%
# Create a thread
config = {"configurable": {"thread_id": "1"}}

# Start conversation
for chunk in graph.stream({"messages": [HumanMessage(content="hi! I'm Lance")]}, config, stream_mode="updates"):
    print(chunk)
# Out:
# {'conversation': {'messages': AIMessage(content="Hi Lance! It's nice to meet you. How are you doing today?", additional_kwargs={}, response_metadata={'model': 'gemma4:31b', 'created_at': '2026-08-12T16:32:19.792387324Z', 'done': True, 'done_reason': 'stop', 'total_duration': 3078235648, 'load_duration': None, 'prompt_eval_count': 19, 'prompt_eval_duration': None, 'eval_count': 18, 'eval_duration': None, 'model_name': 'gemma4:31b'}, id='lc_run--019ff6d1-3bbe-7c72-953f-0c5edf07f585-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 19, 'output_tokens': 18, 'total_tokens': 37})}}

# %% [markdown]
# Let's now just print the state update.

# %%
# Start conversation
for chunk in graph.stream({"messages": [HumanMessage(content="hi! I'm Lance")]}, config, stream_mode="updates"):
    chunk['conversation']["messages"].pretty_print()
# Out:
# ================================== Ai Message ==================================
#
# Hi again, Lance! We just met, but I'm still happy to say hello. Is there anything on your mind or anything I can help you with today?

# %% [markdown]
# Now, we can see `stream_mode="values"`.
#
# This is the `full state` of the graph after the `conversation` node is called.

# %%
# Start conversation, again
config = {"configurable": {"thread_id": "1"}}

# Start conversation
input_message = HumanMessage(content="hi! I'm Lance")
for event in graph.stream({"messages": [input_message]}, config, stream_mode="values"):
    for m in event['messages']:
        m.pretty_print()
    print("---"*25)
# Out:
# ================================ Human Message =================================
#
# hi! I'm Lance
# ================================== Ai Message ==================================
#
# Hi Lance! It's nice to meet you. How are you doing today?
# ================================ Human Message =================================
#
# hi! I'm Lance
# ================================== Ai Message ==================================
#
# Hi again, Lance! We just met, but I'm still happy to say hello. Is there anything on your mind or anything I can help you with today?
# ================================ Human Message =================================
#
# hi! I'm Lance
# ---------------------------------------------------------------------------
# ================================ Human Message =================================
#
# hi! I'm Lance
# ================================== Ai Message ==================================
#
# Hi Lance! It's nice to meet you. How are you doing today?
# ================================ Human Message =================================
#
# hi! I'm Lance
# ================================== Ai Message ==================================
#
# Hi again, Lance! We just met, but I'm still happy to say hello. Is there anything on your mind or anything I can help you with today?
# ================================ Human Message =================================
#
# hi! I'm Lance
# ================================== Ai Message ==================================
#
# Hi Lance! You've definitely made your introduction. 😄
#
# Is there something specific you'd like to talk about, or are you just testing to see if I remember you? I'm here whenever you're ready to chat!
# ---------------------------------------------------------------------------

# %% [markdown]
# ### Streaming tokens
#
# We often want to stream more than graph state.
#
# In particular, with chat model calls it is common to stream the tokens as they are generated.
#
# We can do this [using the `.astream_events` method](https://langchain-ai.github.io/langgraph/how-tos/streaming-from-final-node/#stream-outputs-from-the-final-node), which streams back events as they happen inside nodes!
#
# Each event is a dict with a few keys:
#
# * `event`: This is the type of event that is being emitted.
# * `name`: This is the name of event.
# * `data`: This is the data associated with the event.
# * `metadata`: Contains`langgraph_node`, the node emitting the event.
#
# Let's have a look.

# %%
config = {"configurable": {"thread_id": "2"}}
input_message = HumanMessage(content="Tell me about the 49ers NFL team")
async for event in graph.astream_events({"messages": [input_message]}, config, version="v2"):
    print(f"Node: {event['metadata'].get('langgraph_node','')}. Type: {event['event']}. Name: {event['name']}")
# Out:
# Node: . Type: on_chain_start. Name: LangGraph
# Node: conversation. Type: on_chain_start. Name: conversation
# Node: conversation. Type: on_chat_model_start. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_stream. Name: ChatOllama
# Node: conversation. Type: on_chat_model_end. Name: ChatOllama
# Node: conversation. Type: on_chain_start. Name: should_continue
# Node: conversation. Type: on_chain_end. Name: should_continue
# Node: conversation. Type: on_chain_stream. Name: conversation
# Node: conversation. Type: on_chain_end. Name: conversation
# Node: . Type: on_chain_stream. Name: LangGraph
# Node: . Type: on_chain_end. Name: LangGraph

# %% [markdown]
# The central point is that tokens from chat models within your graph have the `on_chat_model_stream` type.
#
# We can use `event['metadata']['langgraph_node']` to select the node to stream from.
#
# And we can use `event['data']` to get the actual data for each event, which in this case is an `AIMessageChunk`.

# %%
node_to_stream = 'conversation'
config = {"configurable": {"thread_id": "3"}}
input_message = HumanMessage(content="Tell me about the 49ers NFL team")
async for event in graph.astream_events({"messages": [input_message]}, config, version="v2"):
    # Get chat model tokens from a particular node 
    if event["event"] == "on_chat_model_stream" and event['metadata'].get('langgraph_node','') == node_to_stream:
        print(event["data"])
# Out:
# {'chunk': AIMessageChunk(content='The', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' **', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='San', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Francisco', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' ', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='4', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='9', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='ers', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='**', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' are', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' one', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' of', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' the', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' most', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' storied', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' and', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' successful', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' franchises', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' in', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' the', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' National', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Football', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' League', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' (', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='NFL', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=').', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Based', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' in', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Santa', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Clara', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=',', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' California', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' (', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='though', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' they', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' represent', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' San', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Francisco', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='),', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' they', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' compete', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' in', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' the', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' NFC', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' West', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' division', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='.', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='\n\n', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='Here', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' is', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' a', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' comprehensive', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' breakdown', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' of', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' the', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' team', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=':', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='\n\n', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='###', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' ', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='1', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='.', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' History', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' and', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Legacy', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='\n', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='The', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' ', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='4', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='9', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='ers', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' were', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' founded', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' in', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' ', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='1', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='9', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='5', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='5', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=',', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' taking', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' their', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' name', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' from', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' the', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' "', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='fort', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='y', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='-', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='nin', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='ers', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='"', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' who', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' rushed', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' to', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' California', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' during', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' the', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' ', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='1', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='8', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='4', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='9', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Gold', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Rush', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='.', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' While', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' they', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' struggled', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' in', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' their', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' early', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' years', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=',', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' they', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' became', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' a', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' global', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' powerhouse', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' in', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' the', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' ', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='1', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='9', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='8', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='0', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='s', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' and', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' early', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' ', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='9', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='0', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='s', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='.', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='\n\n', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='*', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='   ', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='**', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='The', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Dynasty', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=':**', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Under', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' the', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' leadership', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' of', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' head', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' coach', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' **', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='Bill', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Walsh', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='**', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' and', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' quarterback', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' **', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='Joe', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Montana', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='**,', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' the', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' ', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='4', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='9', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='ers', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' revolutionized', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' football', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' with', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' the', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' "', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='West', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Coast', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Off', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='ense', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=',"', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' a', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' system', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' based', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' on', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' short', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=',', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' precise', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' passing', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' to', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' move', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' the', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' ball', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='.', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='\n', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='*', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='   ', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='**', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='Super', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Bowl', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Success', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=':**', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' The', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' team', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' has', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' won', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' **', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='five', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Super', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Bowl', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' championships', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='**', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' (', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='XVI', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=',', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' XIX', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=',', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' XXIII', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=',', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' XXIV', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=',', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' and', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' XX', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='IX', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=').', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='\n', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='*', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='   ', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='**', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='The', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Steve', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Young', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Era', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=':**', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' After', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Montana', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=',', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Steve', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Young', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' took', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' over', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' as', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' quarterback', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=',', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' continuing', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' the', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' team', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content="'", additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='s', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' dominance', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' and', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' winning', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' a', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# ...
# {'chunk': AIMessageChunk(content=' |', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='\n', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='|', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' :', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='---', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' |', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' :', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='---', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' |', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='\n', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='|', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' **', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='Founded', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='**', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' |', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' ', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='1', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='9', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='5', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='5', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' |', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='\n', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='|', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' **', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='Super', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Bowl', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Wins', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='**', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' |', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' ', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='5', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' |', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='\n', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='|', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' **', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='Hall', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' of', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Fame', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Icons', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='**', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' |', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Joe', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Montana', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=',', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Steve', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Young', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=',', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Ronnie', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' L', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='ott', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=',', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Jerry', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Rice', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' |', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='\n', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='|', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' **', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='Current', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Coach', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='**', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' |', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Kyle', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Shan', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='ahan', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' |', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='\n', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='|', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' **', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='Primary', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Colors', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='**', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' |', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Scarlet', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Red', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' and', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' Gold', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content=' |', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='', additional_kwargs={}, response_metadata={'model': 'gemma4:31b', 'created_at': '2026-08-12T16:46:38.016152227Z', 'done': True, 'done_reason': 'stop', 'total_duration': 8328074557, 'load_duration': None, 'prompt_eval_count': 23, 'prompt_eval_duration': None, 'eval_count': 811, 'eval_duration': None, 'model_name': 'gemma4:31b'}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 23, 'output_tokens': 811, 'total_tokens': 834}, tool_call_chunks=[])}
# {'chunk': AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='lc_run--019ff6de-400e-7782-ac18-5ce3ee68fd22', tool_calls=[], invalid_tool_calls=[], tool_call_chunks=[], chunk_position='last')}

# %% [markdown]
# As you see above, just use the `chunk` key to get the `AIMessageChunk`.

# %%
config = {"configurable": {"thread_id": "4"}}
input_message = HumanMessage(content="Tell me about the 49ers NFL team")
async for event in graph.astream_events({"messages": [input_message]}, config, version="v2"):
    # Get chat model tokens from a particular node 
    if event["event"] == "on_chat_model_stream" and event['metadata'].get('langgraph_node','') == node_to_stream:
        data = event["data"]
        print(data["chunk"].content, end="|")
# Out:
# The| **|San| Francisco| |4|9|ers|**| are| one| of| the| most| storied| and| successful| franchises| in| the| National| Football| League| (|NFL|).| Based| in| the| San| Francisco| Bay| Area|,| they| play| in| the| NFC| West| division|.|
#
# |Here| is| a| comprehensive| breakdown| of| the| team|:|
#
# |###| |1|.| Historical| Legacy| (|The| Dynasty|)|
# |The| |4|9|ers| are| most| famous| for| their| dominance| in| the| |1|9|8|0|s| and| early| |1|9|9|0|s|.| Under| the| leadership| of| head| coach| **|Bill| Walsh|**| and| legendary| quarterback| **|Joe| Montana|**,| the| team| revolutionized| football| with| the| "|West| Coast| Off|ense|"—|a| system| based| on| short|,| precise| passing| and| timing|.|
#
# |*|   |**|Super| Bowl| Success|:**| They| have| won| **|five| Super| Bowl| championships|**| (|XVI|,| XIX|,| XXIII|,| XXIV|,| and| XX|IX|).|
# |*|   |**|The| Montana|-|Young| Era|:**| Joe| Montana| led| the| team| to| four| titles|,| and| Steve| Young| followed| with| a| fifth|,| establishing| the| |4|9|ers| as| the| gold| standard| of| the| era|.|
#
# |###| |2|.| Team| Identity| and| Culture|
# |The| |4|9|ers| are| known| for| a| "|winning| culture|"| and| a| physical|,| aggressive| style| of| play|.| |
# |*|   |**|The| Colors|:**| Their| iconic| colors| are| scarlet| red| and| gold|.|
# |*|   |**|The| Name|:**| The| name| "|4|9|ers|"| is| a| tribute| to| the| gold| seekers| who| rushed| to| California| during| the| |1|8|4|9| Gold| Rush|.|
# |*|   |**|The| Stadium|:**| They| currently| play| at| **|Levi|'|s| Stadium|**| in| Santa| Clara|,| California|.|
#
# |###| |3|.| Current| State| of| the| Team|
# |After| a| period| of| rebuilding| in| the| |2|0|1|0|s|,| the| |4|9|ers| have| returned| to| being| a| perennial| Super| Bowl| contender| under| head| coach| **|Kyle| Shan|ahan|**.|
#
# |*|   |**|The| System|:**| Shan|ahan| is| widely| considered| one| of| the| best| offensive| minds| in| the| league|.| His| system| emphasizes| "|outside| zone|"| running| and| creative| play|-|design| that| makes| players| look| better| than| they| are|.|
# |*|   |**|Key| Players|:**| |
# |    |*|   |**|Brock| Pur|dy|:**| An| unlikely| star| who| went| from| the| very| last| pick| of| the| NFL| Draft| to| a| high|-|efficiency| Pro| Bowl| quarterback|.|
# |    |*|   |**|Christian| McC|aff|rey|:**| One| of| the| most| versatile| weapons| in| NFL| history|,| capable| of| dominating| as| both| a| runner| and| a| receiver|.|
# |    |*|   |**|Nick| B|osa|:**| A| powerhouse| defensive| end| and| one| of| the| most| feared| pass|-|rush|ers| in| the| league|.|
# |    |*|   |**|Fred| Warner|:**| Often| cited| as| the| best| middle| linebacker| in| the| NFL|.|
#
# |###| |4|.| Recent| Performance|
# |In| recent| years|,| the| |4|9|ers| have| been| one| of| the| most| talented| rosters| in| the| league|,| though| they| have| faced| heartbreak| in| the| biggest| games|.| They| reached| **|Super| Bowl| L|VIII|**| (|February| |2|0|2|4|),| where| they| narrowly| lost| to| the| Kansas| City| Chiefs|.| Despite| the| loss|,| they| remain| a| top|-|tier| team| that| consistently| competes| for| the| NFC| Championship|.|
#
# |###| |5|.| Famous| Alumni| (|Hall| of| Fam|ers|)|
# |If| you| are| looking| at| the| team|'|s| history|,| these| are| the| names| that| define| the| franchise|:|
# |*|   |**|Joe| Montana|:**| The| "|cool|est|"| QB| in| history|.|
# |*|   |**|Jerry| Rice|:**| Wid|ely| considered| the| greatest| wide| receiver| to| ever| play| the| game|.|
# |*|   |**|Ron|nie| L|ott|:**| One| of| the| hardest|-|hitting| and| most| versatile| defensive| backs| in| history|.|
# |*|   |**|Steve| Young|:**| A| dual|-|threat| QB| who| holds| many| passing| records|.|
#
# |###| Summary|
# |The| San| Francisco| |4|9|ers| are| a| "|blue| blood|"| NFL| franchise|.| Whether| it| was| the| precision| of| the| |8|0|s| or| the| physical| dominance| of| the| |2|0|2|0|s|,| they| are| almost| always| in| the| conversation| as| one| of| the| best| teams| in| the| league|.||||

# %% [markdown]
# ### Streaming with LangGraph API
#
# **⚠️ DISCLAIMER**
#
# Since the filming of these videos, we've updated Studio so that it can be run locally and opened in your browser. This is now the preferred way to run Studio (rather than using the Desktop App as shown in the video). See documentation [here](https://langchain-ai.github.io/langgraph/concepts/langgraph_studio/#local-development-server) on the local development server and [here](https://langchain-ai.github.io/langgraph/how-tos/local-studio/#run-the-development-server). To start the local development server, run the following command in your terminal in the `/studio` directory in this module:
#
# ```
# langgraph dev
# ```
#
# You should see the following output:
# ```
# - 🚀 API: http://127.0.0.1:2024
# - 🎨 Studio UI: https://smith.langchain.com/studio/?baseUrl=http://127.0.0.1:2024
# - 📚 API Docs: http://127.0.0.1:2024/docs
# ```
#
# Open your browser and navigate to the Studio UI: `https://smith.langchain.com/studio/?baseUrl=http://127.0.0.1:2024`.
#
# The LangGraph API [supports editing graph state](https://langchain-ai.github.io/langgraph/cloud/how-tos/human_in_the_loop_edit_state/#initial-invocation).

# %%
if 'google.colab' in str(get_ipython()):
    raise Exception("Unfortunately LangGraph Studio is currently not supported on Google Colab")

# %%
from langgraph_sdk import get_client

# This is the URL of the local development server
URL = "http://127.0.0.1:2024"
client = get_client(url=URL)

# Search all hosted graphs
assistants = await client.assistants.search()

# %% [markdown]
# Let's [stream `values`](https://langchain-ai.github.io/langgraph/cloud/how-tos/stream_values/), like before.

# %%
# Create a new thread
thread = await client.threads.create()
# Input message
input_message = HumanMessage(content="Multiply 2 and 3")
async for event in client.runs.stream(thread["thread_id"], 
                                      assistant_id="agent", 
                                      input={"messages": [input_message]}, 
                                      stream_mode="values"):
    print(event)
# Out:
# StreamPart(event='metadata', data={'run_id': '1ef6a3d0-41eb-66f4-a311-8ebdfa1b281f'})
# StreamPart(event='values', data={'messages': [{'content': 'Multiply 2 and 3', 'additional_kwargs': {'example': False, 'additional_kwargs': {}, 'response_metadata': {}}, 'response_metadata': {}, 'type': 'human', 'name': None, 'id': '345c67cf-c958-4f89-b787-540fc025080c', 'example': False}]})
# StreamPart(event='values', data={'messages': [{'content': 'Multiply 2 and 3', 'additional_kwargs': {'example': False, 'additional_kwargs': {}, 'response_metadata': {}}, 'response_metadata': {}, 'type': 'human', 'name': None, 'id': '345c67cf-c958-4f89-b787-540fc025080c', 'example': False}, {'content': '', 'additional_kwargs': {'tool_calls': [{'index': 0, 'id': 'call_iIPryzZZxRtXozwwhVtFObNO', 'function': {'arguments': '{"a":2,"b":3}', 'name': 'multiply'}, 'type': 'function'}]}, 'response_metadata': {'finish_reason': 'tool_calls', 'model_name': 'gpt-4o-2024-05-13', 'system_fingerprint': 'fp_157b3831f5'}, 'type': 'ai', 'name': None, 'id': 'run-88179a6d-eb1e-4953-ac42-0b533b6d76f6', 'example': False, 'tool_calls': [{'name': 'multiply', 'args': {'a': 2, 'b': 3}, 'id': 'call_iIPryzZZxRtXozwwhVtFObNO', 'type': 'tool_call'}], 'invalid_tool_calls': [], 'usage_metadata': None}]})
# StreamPart(event='values', data={'messages': [{'content': 'Multiply 2 and 3', 'additional_kwargs': {'example': False, 'additional_kwargs': {}, 'response_metadata': {}}, 'response_metadata': {}, 'type': 'human', 'name': None, 'id': '345c67cf-c958-4f89-b787-540fc025080c', 'example': False}, {'content': '', 'additional_kwargs': {'tool_calls': [{'index': 0, 'id': 'call_iIPryzZZxRtXozwwhVtFObNO', 'function': {'arguments': '{"a":2,"b":3}', 'name': 'multiply'}, 'type': 'function'}]}, 'response_metadata': {'finish_reason': 'tool_calls', 'model_name': 'gpt-4o-2024-05-13', 'system_fingerprint': 'fp_157b3831f5'}, 'type': 'ai', 'name': None, 'id': 'run-88179a6d-eb1e-4953-ac42-0b533b6d76f6', 'example': False, 'tool_calls': [{'name': 'multiply', 'args': {'a': 2, 'b': 3}, 'id': 'call_iIPryzZZxRtXozwwhVtFObNO', 'type': 'tool_call'}], 'invalid_tool_calls': [], 'usage_metadata': None}, {'content': '6', 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'tool', 'name': 'multiply', 'id': '4dd5ce10-ac0b-4a91-b34b-c35109dcbf29', 'tool_call_id': 'call_iIPryzZZxRtXozwwhVtFObNO', 'artifact': None, 'status': 'success'}]})
# StreamPart(event='values', data={'messages': [{'content': 'Multiply 2 and 3', 'additional_kwargs': {'example': False, 'additional_kwargs': {}, 'response_metadata': {}}, 'response_metadata': {}, 'type': 'human', 'name': None, 'id': '345c67cf-c958-4f89-b787-540fc025080c', 'example': False}, {'content': '', 'additional_kwargs': {'tool_calls': [{'index': 0, 'id': 'call_iIPryzZZxRtXozwwhVtFObNO', 'function': {'arguments': '{"a":2,"b":3}', 'name': 'multiply'}, 'type': 'function'}]}, 'response_metadata': {'finish_reason': 'tool_calls', 'model_name': 'gpt-4o-2024-05-13', 'system_fingerprint': 'fp_157b3831f5'}, 'type': 'ai', 'name': None, 'id': 'run-88179a6d-eb1e-4953-ac42-0b533b6d76f6', 'example': False, 'tool_calls': [{'name': 'multiply', 'args': {'a': 2, 'b': 3}, 'id': 'call_iIPryzZZxRtXozwwhVtFObNO', 'type': 'tool_call'}], 'invalid_tool_calls': [], 'usage_metadata': None}, {'content': '6', 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'tool', 'name': 'multiply', 'id': '4dd5ce10-ac0b-4a91-b34b-c35109dcbf29', 'tool_call_id': 'call_iIPryzZZxRtXozwwhVtFObNO', 'artifact': None, 'status': 'success'}, {'content': 'The result of multiplying 2 and 3 is 6.', 'additional_kwargs': {}, 'response_metadata': {'finish_reason': 'stop', 'model_name': 'gpt-4o-2024-05-13', 'system_fingerprint': 'fp_157b3831f5'}, 'type': 'ai', 'name': None, 'id': 'run-b5862486-a25f-48fc-9a03-a8506a6692a8', 'example': False, 'tool_calls': [], 'invalid_tool_calls': [], 'usage_metadata': None}]})

# %% [markdown]
# The streamed objects have:
#
# * `event`: Type
# * `data`: State

# %%
from langchain_core.messages import convert_to_messages
thread = await client.threads.create()
input_message = HumanMessage(content="Multiply 2 and 3")
async for event in client.runs.stream(thread["thread_id"], assistant_id="agent", input={"messages": [input_message]}, stream_mode="values"):
    messages = event.data.get('messages',None)
    if messages:
        print(convert_to_messages(messages)[-1])
    print('='*25)
# Out:
# =========================
# content='Multiply 2 and 3' additional_kwargs={'additional_kwargs': {'example': False, 'additional_kwargs': {}, 'response_metadata': {}}, 'response_metadata': {}, 'example': False} id='f51807de-6b99-4da4-a798-26cf59d16412'
# =========================
# content='' additional_kwargs={'additional_kwargs': {'tool_calls': [{'index': 0, 'id': 'call_imZHAw7kvMR2ZeKaQVSlj25C', 'function': {'arguments': '{"a":2,"b":3}', 'name': 'multiply'}, 'type': 'function'}]}, 'response_metadata': {'finish_reason': 'tool_calls', 'model_name': 'gpt-4o-2024-05-13', 'system_fingerprint': 'fp_157b3831f5'}, 'example': False, 'invalid_tool_calls': [], 'usage_metadata': None} id='run-fa4ab1c6-274d-4be5-8c4a-a6411c7c35cc' tool_calls=[{'name': 'multiply', 'args': {'a': 2, 'b': 3}, 'id': 'call_imZHAw7kvMR2ZeKaQVSlj25C', 'type': 'tool_call'}]
# =========================
# content='6' additional_kwargs={'additional_kwargs': {}, 'response_metadata': {}, 'status': 'success'} name='multiply' id='3e7bbfb6-aa82-453a-969c-9c753fbd1d74' tool_call_id='call_imZHAw7kvMR2ZeKaQVSlj25C'
# =========================
# content='The result of multiplying 2 and 3 is 6.' additional_kwargs={'additional_kwargs': {}, 'response_metadata': {'finish_reason': 'stop', 'model_name': 'gpt-4o-2024-05-13', 'system_fingerprint': 'fp_157b3831f5'}, 'example': False, 'invalid_tool_calls': [], 'usage_metadata': None} id='run-e8e0d672-cfb2-42be-850a-345df3718f69'
# =========================

# %% [markdown]
# There are some new streaming mode that are only supported via the API.
#
# For example, we can [use `messages` mode](https://langchain-ai.github.io/langgraph/cloud/how-tos/stream_messages/) to better handle the above case!
#
# This mode currently assumes that you have a `messages` key in your graph, which is a list of messages.
#
# All events emitted using `messages` mode have two attributes:
#
# * `event`: This is the name of the event
# * `data`: This is data associated with the event

# %%
thread = await client.threads.create()
input_message = HumanMessage(content="Multiply 2 and 3")
async for event in client.runs.stream(thread["thread_id"], 
                                      assistant_id="agent", 
                                      input={"messages": [input_message]}, 
                                      stream_mode="messages"):
    print(event.event)
# Out:
# metadata
# messages/complete
# messages/metadata
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/complete
# messages/complete
# messages/metadata
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/complete

# %% [markdown]
# We can see a few events:
#
# * `metadata`: metadata about the run
# * `messages/complete`: fully formed message
# * `messages/partial`: chat model tokens
#
# You can dig further into the types [here](https://langchain-ai.github.io/langgraph/cloud/concepts/api/#modemessages).
#
# Now, let's show how to stream these messages.
#
# We'll define a helper function for better formatting of the tool calls in messages.

# %%
thread = await client.threads.create()
input_message = HumanMessage(content="Multiply 2 and 3")

def format_tool_calls(tool_calls):
    """
    Format a list of tool calls into a readable string.

    Args:
        tool_calls (list): A list of dictionaries, each representing a tool call.
            Each dictionary should have 'id', 'name', and 'args' keys.

    Returns:
        str: A formatted string of tool calls, or "No tool calls" if the list is empty.

    """

    if tool_calls:
        formatted_calls = []
        for call in tool_calls:
            formatted_calls.append(
                f"Tool Call ID: {call['id']}, Function: {call['name']}, Arguments: {call['args']}"
            )
        return "\n".join(formatted_calls)
    return "No tool calls"

async for event in client.runs.stream(
    thread["thread_id"],
    assistant_id="agent",
    input={"messages": [input_message]},
    stream_mode="messages",):
    
    # Handle metadata events
    if event.event == "metadata":
        print(f"Metadata: Run ID - {event.data['run_id']}")
        print("-" * 50)
    
    # Handle partial message events
    elif event.event == "messages/partial":
        for data_item in event.data:
            # Process user messages
            if "role" in data_item and data_item["role"] == "user":
                print(f"Human: {data_item['content']}")
            else:
                # Extract relevant data from the event
                tool_calls = data_item.get("tool_calls", [])
                invalid_tool_calls = data_item.get("invalid_tool_calls", [])
                content = data_item.get("content", "")
                response_metadata = data_item.get("response_metadata", {})

                if content:
                    print(f"AI: {content}")

                if tool_calls:
                    print("Tool Calls:")
                    print(format_tool_calls(tool_calls))

                if invalid_tool_calls:
                    print("Invalid Tool Calls:")
                    print(format_tool_calls(invalid_tool_calls))

                if response_metadata:
                    finish_reason = response_metadata.get("finish_reason", "N/A")
                    print(f"Response Metadata: Finish Reason - {finish_reason}")
                    
        print("-" * 50)
# Out:
# Metadata: Run ID - 1ef6a3da-687f-6253-915a-701de5327165
# --------------------------------------------------
# Tool Calls:
# Tool Call ID: call_IL4MGMtr1fEpR3Yd9c2goLd8, Function: multiply, Arguments: {}
# --------------------------------------------------
# Tool Calls:
# Tool Call ID: call_IL4MGMtr1fEpR3Yd9c2goLd8, Function: multiply, Arguments: {}
# --------------------------------------------------
# Tool Calls:
# Tool Call ID: call_IL4MGMtr1fEpR3Yd9c2goLd8, Function: multiply, Arguments: {}
# --------------------------------------------------
# Tool Calls:
# Tool Call ID: call_IL4MGMtr1fEpR3Yd9c2goLd8, Function: multiply, Arguments: {}
# --------------------------------------------------
# Tool Calls:
# Tool Call ID: call_IL4MGMtr1fEpR3Yd9c2goLd8, Function: multiply, Arguments: {'a': 2}
# --------------------------------------------------
# Tool Calls:
# Tool Call ID: call_IL4MGMtr1fEpR3Yd9c2goLd8, Function: multiply, Arguments: {'a': 2}
# --------------------------------------------------
# Tool Calls:
# Tool Call ID: call_IL4MGMtr1fEpR3Yd9c2goLd8, Function: multiply, Arguments: {'a': 2}
# --------------------------------------------------
# Tool Calls:
# Tool Call ID: call_IL4MGMtr1fEpR3Yd9c2goLd8, Function: multiply, Arguments: {'a': 2}
# --------------------------------------------------
# Tool Calls:
# Tool Call ID: call_IL4MGMtr1fEpR3Yd9c2goLd8, Function: multiply, Arguments: {'a': 2, 'b': 3}
# --------------------------------------------------
# Tool Calls:
# Tool Call ID: call_IL4MGMtr1fEpR3Yd9c2goLd8, Function: multiply, Arguments: {'a': 2, 'b': 3}
# --------------------------------------------------
# Tool Calls:
# Tool Call ID: call_IL4MGMtr1fEpR3Yd9c2goLd8, Function: multiply, Arguments: {'a': 2, 'b': 3}
# Response Metadata: Finish Reason - tool_calls
# --------------------------------------------------
# --------------------------------------------------
# AI: The
# --------------------------------------------------
# AI: The result
# --------------------------------------------------
# AI: The result of
# --------------------------------------------------
# AI: The result of multiplying
# --------------------------------------------------
# AI: The result of multiplying
# --------------------------------------------------
# AI: The result of multiplying 2
# --------------------------------------------------
# AI: The result of multiplying 2 and
# --------------------------------------------------
# AI: The result of multiplying 2 and
# --------------------------------------------------
# AI: The result of multiplying 2 and 3
# --------------------------------------------------
# AI: The result of multiplying 2 and 3 is
# --------------------------------------------------
# AI: The result of multiplying 2 and 3 is
# --------------------------------------------------
# AI: The result of multiplying 2 and 3 is 6
# --------------------------------------------------
# AI: The result of multiplying 2 and 3 is 6.
# --------------------------------------------------
# AI: The result of multiplying 2 and 3 is 6.
# Response Metadata: Finish Reason - stop
# --------------------------------------------------
